# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

import os
import PIL
import numpy as np
import matplotlib.pyplot as plt

from torchvision.models import resnet18

model = resnet18(weights="IMAGENET1K_V1")
model.fc = nn.Linear(in_features=model.fc.in_features, out_features=2)
! unzip -q /content/drive/MyDrive/Datasets/Cats\&Dogs.zip

class CatsDogs(Dataset):
    def __init__(self, root_path, transform):
        self.root_path = root_path
        self.imgs_path = []
        self.labels = []
        self.transform = transform

        for id, class_name in enumerate(os.listdir(self.root_path)):
            class_path = os.path.join(self.root_path, class_name)
            for img_name in os.listdir(class_path):
                img_path = os.path.join(self.root_path, class_name, img_name)
                # cv2.imread(img_path)
                self.imgs_path.append(img_path)
                self.labels.append(id)

    def __len__(self):
        return len(self.imgs_path)

    def __getitem__(self, idx):
        img = PIL.Image.open(self.imgs_path[idx])
        label = self.labels[idx]

        img = self.transform(img)

        return img, label


from sklearn.metrics import accuracy_score


def train(loader, model, criterion, optimizer, device):
    model.train()
    loss_per_epoch = []
    acc_per_epoch = []
    for data, label in loader:
        optimizer.zero_grad()

        data = data.to(device)
        label = label.to(device)

        pred = model(data)
        loss = criterion(pred, label)
        loss.backward()
        optimizer.step()

        acc = accuracy_score(label.detach().cpu(), pred.argmax(dim=1).detach().cpu())
        acc_per_epoch.append(acc)
        loss_per_epoch.append(loss.item())

    return torch.mean(torch.tensor(loss_per_epoch)), torch.mean(torch.tensor(acc_per_epoch))


def test(loader, model, criterion, device):
    model.eval()
    loss_per_epoch = []
    acc_per_epoch = []
    with torch.no_grad():
        for data, label in loader:
            data = data.to(device)
            label = label.to(device)

            pred = model(data)
            loss = criterion(pred, label)
            acc = accuracy_score(label.detach().cpu(), pred.argmax(dim=1).detach().cpu())
            acc_per_epoch.append(acc)
            loss_per_epoch.append(loss.item())

    return torch.mean(torch.tensor(loss_per_epoch)), torch.mean(torch.tensor(acc_per_epoch))


import torchvision

transfrom = torchvision.transforms.Compose([
    torchvision.transforms.Resize(256),
    torchvision.transforms.CenterCrop(224),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

train_data = CatsDogs(root_path='/content/dataset/training_set', transform=transfrom)
test_data = CatsDogs(root_path='/content/dataset/test_set', transform=transfrom)

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)
model = resnet18(weights="IMAGENET1K_V1")
model.fc = nn.Linear(in_features=model.fc.in_features, out_features=2)
model.requires_grad = False
model.fc.requires_grad = True
device = 'cuda'
optimizer = torch.optim.SGD(model.parameters(), lr=0.001)
criterion = torch.nn.CrossEntropyLoss()
model = model.to(device)

train_loss_per_epoch = []
train_acc_per_epoch = []
test_loss_per_epoch = []
test_acc_per_epoch = []
for epoch in range(10):
    train_loss, train_acc = train(train_loader, model, criterion, optimizer, device)
    test_loss, test_acc = test(test_loader, model, criterion, device)
    train_loss_per_epoch.append(train_loss)
    train_acc_per_epoch.append(train_acc)
    test_loss_per_epoch.append(test_loss)
    test_acc_per_epoch.append(test_acc)
    print(
        f"Epoch {epoch + 1}/10: Train loss: {train_loss}, Train acc: {train_acc}, Test loss: {test_loss}, Test acc: {test_acc}")

model = resnet18(weights="IMAGENET1K_V1")
model.fc = nn.Linear(in_features=model.fc.in_features, out_features=2)
model = model.to(device)
test_loss, test_acc = test(test_loader, model, criterion, device)
test_acc
model = resnet18(weights="IMAGENET1K_V1")
model.fc = nn.Linear(in_features=model.fc.in_features, out_features=2)
device = 'cuda'
optimizer = torch.optim.SGD(model.parameters(), lr=0.001)
criterion = torch.nn.CrossEntropyLoss()
model = model.to(device)

train_loss_per_epoch = []
train_acc_per_epoch = []
test_loss_per_epoch = []
test_acc_per_epoch = []
for epoch in range(10):
    train_loss, train_acc = train(train_loader, model, criterion, optimizer, device)
    test_loss, test_acc = test(test_loader, model, criterion, device)
    train_loss_per_epoch.append(train_loss)
    train_acc_per_epoch.append(train_acc)
    test_loss_per_epoch.append(test_loss)
    test_acc_per_epoch.append(test_acc)
    print(
        f"Epoch {epoch + 1}/10: Train loss: {train_loss}, Train acc: {train_acc}, Test loss: {test_loss}, Test acc: {test_acc}")

model = resnet18(weights="IMAGENET1K_V1")
model.fc = nn.Linear(in_features=model.fc.in_features, out_features=2)
device = 'cuda'
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()
model = model.to(device)

train_loss_per_epoch = []
train_acc_per_epoch = []
test_loss_per_epoch = []
test_acc_per_epoch = []
for epoch in range(10):
    train_loss, train_acc = train(train_loader, model, criterion, optimizer, device)
    test_loss, test_acc = test(test_loader, model, criterion, device)
    train_loss_per_epoch.append(train_loss)
    train_acc_per_epoch.append(train_acc)
    test_loss_per_epoch.append(test_loss)
    test_acc_per_epoch.append(test_acc)
    print(
        f"Epoch {epoch + 1}/10: Train loss: {train_loss}, Train acc: {train_acc}, Test loss: {test_loss}, Test acc: {test_acc}")

model = resnet18(weights="IMAGENET1K_V1")
model.fc = nn.Linear(in_features=model.fc.in_features, out_features=2)
model.requires_grad = False
model.fc.requires_grad = True
device = 'cuda'
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()
model = model.to(device)

train_loss_per_epoch = []
train_acc_per_epoch = []
test_loss_per_epoch = []
test_acc_per_epoch = []
for epoch in range(10):
    train_loss, train_acc = train(train_loader, model, criterion, optimizer, device)
    test_loss, test_acc = test(test_loader, model, criterion, device)
    train_loss_per_epoch.append(train_loss)
    train_acc_per_epoch.append(train_acc)
    test_loss_per_epoch.append(test_loss)
    test_acc_per_epoch.append(test_acc)
    print(
        f"Epoch {epoch + 1}/10: Train loss: {train_loss}, Train acc: {train_acc}, Test loss: {test_loss}, Test acc: {test_acc}")
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\Mobina/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:50<00:00, 926kB/s]
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.
# 'Dogs.zip' is not recognized as an internal or external command,
# operable program or batch file.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 95
#      86 import torchvision
#      88 transfrom = torchvision.transforms.Compose([
#      89     torchvision.transforms.Resize(256),
#      90     torchvision.transforms.CenterCrop(224),
#      91     torchvision.transforms.ToTensor(),
#      92     torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#      93 ])
# ---> 95 train_data = CatsDogs(root_path='/content/dataset/training_set', transform=transfrom)
#      96 test_data = CatsDogs(root_path='/content/dataset/test_set', transform=transfrom)
#      98 train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
#
# Cell In[1], line 23, in CatsDogs.__init__(self, root_path, transform)
#      20 self.labels = []
#      21 self.transform = transform
# ---> 23 for id, class_name in enumerate(os.listdir(self.root_path)):
#      24     class_path = os.path.join(self.root_path, class_name)
#      25     for img_name in os.listdir(class_path):
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/content/dataset/training_set'
